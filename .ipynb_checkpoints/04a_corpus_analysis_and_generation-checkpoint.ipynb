# %% [markdown]
# # 4a. Generating and Analyzing Corpus of Abstract Text

# %% [markdown]
# ## Introduction

# %% [markdown]
# This Notebook **generates the corpus of abstract text** taht we will use to train our models. Additionally, it **analyzes and compares the country and year distribution of both the retracted and non-retracted papers** in our corpus.
#
# The Notebook takes as input the abstracts for retracted and non-retracted papers that were extracted in **Notebook 2c** and **Notebook 3c**. The output that it produces will in turn be used by **Notebook 4b** to train our machine learning model.
#
# The **workflow** has thus been set as follows:
#
# - Input: **two .csv files** with abstracts from retracted papers and non-retracted papers, respectively.
# - Output: **one .csv file** with our whole corpus, which combines abstracts from both retracted and non-retracted papers.

# %% [markdown]
# ## Input/Output Parameters:

# %% [markdown]
# Input parameters:

# %%
# File path to abstracts of retracted papers

file_path_retracted = '../data/abstracts/cell_biology/retracted/retracted_cell_biology_abstracts.csv'

# File path to abstracts of non-retracted papers

file_path_non_retracted = '../data/abstracts/cell_biology/non_retracted/non_retracted_cell_biology_abstracts.csv'

# %% [markdown]
# Output path:

# %%
# File path for output file

output_path = "../data/final_corpus.csv"

# %% [markdown]
# ## Importing Libraries

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Abstracts of Retracted Papers

# %% [markdown]
# Let us start by loading the abstracts of our retracted papers into a data frame:

# %%
# Load abstracts of non-retracted papers from .csv file

df_retracted = pd.read_csv(file_path_retracted, delimiter='|')

# Visualize first few entries for verification

df_retracted.head()
# Out:
#                                        abstract_text  target  \
# 0  "Vascular endothelial growth factor receptor-1...       1
# 1  "Type 1 diabetes mellitus (T1DM) is a systemic...       1
# 2  "The study was designed to elucidate the regul...       1
# 3  "Hepatocellular carcinoma (HCC) is the third l...       1
# 4  "BACKGROUND Retinoblastoma is a rare malignanc...       1
#
#                             doi country  year  ret_flag
# 0  10.1371_journal.pone.0065217      CN  2013     False
# 1              10.1002_ptr.6533      CN  2019     False
# 2             10.1002_jcb.29429      CN  2019     False
# 3           10.1155_2014_486407      TW  2014     False
# 4           10.12659_MSM.914242      CN  2019     False

# %% [markdown]
# As we mentioned in previous notebooks, retracted papers sometimes include "retraction notices" in their abstract, stating that the paper in question has been removed from the published record. These notices typically include words such as "retracted" etc. which would cause data leakeage if we were to feed them to our model. We will thus drop all such papers from our data frame, leaving papers for which no retraction notices has been left only:

# %%
# Drop rows with retraction notices from our data frame

df_retracted = df_retracted[df_retracted['ret_flag'] != True]

# Display resulting data frame for verification

df_retracted.head()
# Out:
#                                        abstract_text  target  \
# 0  "Vascular endothelial growth factor receptor-1...       1
# 1  "Type 1 diabetes mellitus (T1DM) is a systemic...       1
# 2  "The study was designed to elucidate the regul...       1
# 3  "Hepatocellular carcinoma (HCC) is the third l...       1
# 4  "BACKGROUND Retinoblastoma is a rare malignanc...       1
#
#                             doi country  year  ret_flag
# 0  10.1371_journal.pone.0065217      CN  2013     False
# 1              10.1002_ptr.6533      CN  2019     False
# 2             10.1002_jcb.29429      CN  2019     False
# 3           10.1155_2014_486407      TW  2014     False
# 4           10.12659_MSM.914242      CN  2019     False

# %% [markdown]
# ## Loading Abstracts of Non-Retracted Papers

# %% [markdown]
# Let us now turn our attention to our non-retracted papers. We will start by loading the .csv file with the text of our non-retracted papers into a separate dataframe:

# %%
# Load the .csv file with abstracts of non-retracted papers into data frame

df_non_retracted = pd.read_csv(file_path_non_retracted, delimiter='|')

# Display first few rows of data frame for verification

df_non_retracted.head()
# Out:
#                                        abstract_text  target  \
# 0  "Src kinase mediates growth factor signaling a...       0
# 1  "Histidine-rich calcium binding protein (HRC) ...       0
# 2  "Significance Animal cells undergo a remarkabl...       0
# 3  "Inositol-requiring enzyme 1 (IRE1) is the mos...       0
# 4  "Abstract Hepatocellular carcinoma (HCC) is th...       0
#
#                           doi country  year  ret_flag
# 0     10.1073_pnas.0701077104      US  2007     False
# 1          10.7150_ijms.60610      CN  2021     False
# 2     10.1073_pnas.1420585112      GB  2015     False
# 3     10.1074_jbc.m110.199737      US  2011     False
# 4  10.1038_s41388-020-01417-6      CN  2020     False

# %% [markdown]
# And once again drop papers with words such as "retracted" etc. in their abstract from our data frame:

# %%
# Drop rows where 'ret_flag' is True 

df_non_retracted = df_non_retracted[df_non_retracted['ret_flag'] != True]

# Display resulting data frame

df_non_retracted.head()
# Out:
#                                        abstract_text  target  \
# 0  "Src kinase mediates growth factor signaling a...       0
# 1  "Histidine-rich calcium binding protein (HRC) ...       0
# 2  "Significance Animal cells undergo a remarkabl...       0
# 3  "Inositol-requiring enzyme 1 (IRE1) is the mos...       0
# 4  "Abstract Hepatocellular carcinoma (HCC) is th...       0
#
#                           doi country  year  ret_flag
# 0     10.1073_pnas.0701077104      US  2007     False
# 1          10.7150_ijms.60610      CN  2021     False
# 2     10.1073_pnas.1420585112      GB  2015     False
# 3     10.1074_jbc.m110.199737      US  2011     False
# 4  10.1038_s41388-020-01417-6      CN  2020     False

# %% [markdown]
# ## Analyzing Country and Year Distribution of both Retracted and Non-Retracted Papers

# %% [markdown]
# Before we go on to , we will analyze the year and country distribution for both our retracted and our non-retracted papers. The extraction process for our non-retracted text was designed so as to make sure. We shall start by creating a data frame that tells us how many retracted papers there are for each country and year:

# %%
# Calculate counts per year and country for retracted papers

retracted_counts = df_retracted.groupby(['country', 'year']).size().reset_index(name='retracted_count')

# Obtain total number of retracted papers for confirmation

print("Total number of retracted papers is:", retracted_counts["retracted_count"].sum())

# Visualize result

retracted_counts.head()
# Out:
# Total number of retracted papers is: 6294
#   country  year  retracted_count
# 0      AR  2009                1
# 1      AR  2011                2
# 2      AR  2013                2
# 3      AT  2000                1
# 4      AT  2009                1

# %% [markdown]
# And same about our non-retracted papers:

# %%
# Calculate value counts per year and country for non-retracted papers

nonretracted_counts = df_non_retracted.groupby(['country', 'year']).size().reset_index(name='non_retracted_count')

# Obtain total number of non-retracted papers for confirmation

print("Total number of non-retracted papers is:", nonretracted_counts["non_retracted_count"].sum())

# Visualize result

nonretracted_counts
# Out:
# Total number of non-retracted papers is: 6689
#     country  year  non_retracted_count
# 0        AR  2010                    1
# 1        AT  2003                    1
# 2        AT  2009                    2
# 3        AT  2010                    1
# 4        AT  2012                    2
# ..      ...   ...                  ...
# 671      ZA  2017                    1
# 672      ZA  2018                    1
# 673      ZA  2020                    2
# 674      ZA  2022                    1
# 675      ZM  2020                    1
#
# [676 rows x 3 columns]

# %% [markdown]
# It will be useful to display these distributions in a plot bar so that we can have an intuitive sense of whether they are similar to each other or not:

# %%
# Creating plot 

plt.figure(figsize=(18, 8))

# Create subplot for non-retracted papers

plt.subplot(2, 1, 1)
plt.bar(nonretracted_counts['country'] + '_' + nonretracted_counts['year'].astype(str), nonretracted_counts['non_retracted_count'])
plt.title('Number of Papers per Country and Year (Non-Retracted)')
plt.xlabel('Country-Year Bucket')
plt.ylabel('Number of Papers')
plt.xticks([]) 

# Create second subplot for retracted papers

plt.subplot(2, 1, 2)
plt.bar(retracted_counts['country'] + '_' + retracted_counts['year'].astype(str), retracted_counts['retracted_count'])
plt.title('Number of Papers per Country-Year (Retracted)')
plt.xlabel('Country_Year')
plt.ylabel('Count')
plt.xticks([]) 


# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# And by creating a data frame with the exact difference between retracted and non-retracted papers for each specific year and country bucket:

# %%
# Merge the dataframes

merged_df = nonretracted_counts.merge(retracted_counts, on=['country', 'year'], how='outer').fillna(0)

# Calculate the difference

merged_df['difference'] = merged_df['non_retracted_count'] - merged_df['retracted_count']

# Count occurrences per year for retracted dataframe

retracted_counts_per_year = df_retracted.groupby('year').size().reset_index(name='retracted_count')

# Merge with the country information

retracted_counts_per_year = retracted_counts_per_year.merge(df_retracted[['year', 'country']], on='year', how='left')

# Calculate total retracted count per country and sort

sorted_countries = retracted_counts_per_year.groupby('country')['retracted_count'].sum().sort_values(ascending=False).index

# Create a dataframe for sorted countries

sorted_df = pd.DataFrame({'country': sorted_countries})

# Merge with original dataframe to retain country-year information

final_df = sorted_df.merge(merged_df, on='country', how='left')

# Display the dataframe

final_df.head(10)
# Out:
#   country  year  non_retracted_count  retracted_count  difference
# 0      CN  1995                  0.0              1.0        -1.0
# 1      CN  2003                  1.0              0.0         1.0
# 2      CN  2004                  4.0              3.0         1.0
# 3      CN  2005                  5.0              5.0         0.0
# 4      CN  2006                  5.0              5.0         0.0
# 5      CN  2007                 12.0              7.0         5.0
# 6      CN  2008                 15.0             16.0        -1.0
# 7      CN  2009                 16.0             14.0         2.0
# 8      CN  2010                 26.0             18.0         8.0
# 9      CN  2011                 62.0             23.0        39.0

# %%
# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['year', 'country'])

# Aggregate data to get total counts per year
yearly_counts = final_df.groupby('year').sum(numeric_only=True).reset_index()

# Generate unique x positions for each year
x_labels = yearly_counts['year'].astype(str)
x_positions = np.arange(len(x_labels))

# Initialize plot
plt.figure(figsize=(15, 7))

# Plot bars for non-retracted and retracted counts
plt.bar(x_positions - 0.2, yearly_counts['non_retracted_count'], width=0.4, label='Non-Retracted', color='blue')
plt.bar(x_positions + 0.2, yearly_counts['retracted_count'], width=0.4, label='Retracted', color='red')

# Formatting
plt.title('Count of Retracted and Non-Retracted Papers per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(x_positions, x_labels, rotation=90)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['country', 'year'])

# Aggregate data to get total counts per country and year
country_year_counts = final_df.groupby(['country', 'year']).sum(numeric_only=True).reset_index()

# Select top 100 entries based on the highest total counts (sum of non-retracted and retracted)
top_100 = country_year_counts.nlargest(100, ['non_retracted_count', 'retracted_count'])

# Generate unique x positions for each country-year pair
x_labels = [f"{row['country']}_{row['year']}" for _, row in top_100.iterrows()]
x_positions = np.arange(len(x_labels))

# Initialize plot
plt.figure(figsize=(18, 8))

# Plot bars for non-retracted and retracted counts
plt.bar(x_positions - 0.2, top_100['non_retracted_count'], width=0.4, label='Non-Retracted', color='blue')
plt.bar(x_positions + 0.2, top_100['retracted_count'], width=0.4, label='Retracted', color='red')

# Formatting
plt.title('Top 100 Counts of Retracted and Non-Retracted Papers per Country-Year')
plt.xlabel('Country-Year')
plt.ylabel('Count')
plt.xticks(x_positions, x_labels, rotation=90)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['country', 'year'])

# Aggregate data to get total counts per country and year
country_year_counts = final_df.groupby(['country', 'year']).sum(numeric_only=True).reset_index()

# Calculate the difference between retracted and non-retracted counts
country_year_counts['difference'] = country_year_counts['retracted_count'] - country_year_counts['non_retracted_count']

# Select top 100 entries based on the highest total counts (sum of non-retracted and retracted)
top_100 = country_year_counts.nlargest(100, ['non_retracted_count', 'retracted_count'])

# Generate unique x positions for each country-year pair
x_labels = [f"{row['country']}_{row['year']}" for _, row in top_100.iterrows()]
x_positions = np.arange(len(x_labels))

# Initialize plot
plt.figure(figsize=(18, 8))

# Plot bars for non-retracted and retracted counts
plt.bar(x_positions - 0.2, top_100['non_retracted_count'], width=0.4, label='Non-Retracted', color='blue')
plt.bar(x_positions + 0.2, top_100['retracted_count'], width=0.4, label='Retracted', color='red')

# Formatting
plt.title('Top 100 Counts of Retracted and Non-Retracted Papers per Country-Year')
plt.xlabel('Country-Year')
plt.ylabel('Count')
plt.xticks(x_positions, x_labels, rotation=90)
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['country', 'year'])

# Aggregate data to get total counts per country and year
country_year_counts = final_df.groupby(['country', 'year']).sum(numeric_only=True).reset_index()

# Calculate the difference between retracted and non-retracted counts
country_year_counts['difference'] = country_year_counts['retracted_count'] - country_year_counts['non_retracted_count']

# Calculate the difference as a percentage of the total papers (avoiding division by zero)
country_year_counts['difference_percentage'] = (country_year_counts['difference'] / (country_year_counts['non_retracted_count'] + country_year_counts['retracted_count']).replace(0, np.nan)) * 100

# Select top 100 entries based on the highest total counts (sum of non-retracted and retracted)
top_100 = country_year_counts.nlargest(100, ['non_retracted_count', 'retracted_count'])

# Generate unique x positions for each country-year pair
x_labels = [f"{row['country']}_{row['year']}" for _, row in top_100.iterrows()]
x_positions = np.arange(len(x_labels))

# Initialize plot
plt.figure(figsize=(18, 8))

# Plot bars for the difference percentage between retracted and non-retracted counts
plt.bar(x_positions, top_100['difference_percentage'], width=0.4, color='purple', label='Difference % (Retracted - Non-Retracted)')

# Formatting
plt.title('Difference Percentage between Retracted and Non-Retracted Papers per Country-Year')
plt.xlabel('Country-Year')
plt.ylabel('Difference (%)')
plt.xticks(x_positions, x_labels, rotation=90)
plt.axhline(0, color='black', linewidth=1)  # Add a reference line at 0
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['country', 'year'])

# Aggregate data to get total counts per country and year
country_year_counts = final_df.groupby(['country', 'year']).sum(numeric_only=True).reset_index()

# Calculate the difference between retracted and non-retracted counts
country_year_counts['difference'] = country_year_counts['retracted_count'] - country_year_counts['non_retracted_count']

# Calculate the difference as a percentage of the total papers (avoiding division by zero)
country_year_counts['difference_percentage'] = (country_year_counts['difference'] / (country_year_counts['non_retracted_count'] + country_year_counts['retracted_count']).replace(0, np.nan)) * 100

# Select top 100 entries based on the highest total counts (sum of non-retracted and retracted)
top_100 = country_year_counts.nlargest(100, ['non_retracted_count', 'retracted_count'])

# Generate unique x positions for each country-year pair
x_labels = [f"{row['country']}_{row['year']}" for _, row in top_100.iterrows()]
x_positions = np.arange(len(x_labels))

# Initialize plot
plt.figure(figsize=(18, 8))

# Plot bars for the difference percentage between retracted and non-retracted counts
plt.bar(x_positions, top_100['difference_percentage'], width=0.4, color='purple', label='Difference % (Retracted - Non-Retracted)')

# Formatting
plt.title('Difference Percentage between Retracted and Non-Retracted Papers per Country-Year')
plt.xlabel('Country-Year')
plt.ylabel('Difference (%)')
plt.xticks(x_positions, x_labels, rotation=90)
plt.axhline(0, color='black', linewidth=1)  # Add a reference line at 0
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Ensure the data is sorted properly
final_df = final_df.sort_values(by=['country', 'year'])

# Aggregate data to get total counts per country and year
country_year_counts = final_df.groupby(['country', 'year']).sum(numeric_only=True).reset_index()

# Calculate the difference between retracted and non-retracted counts
country_year_counts['difference'] = country_year_counts['retracted_count'] - country_year_counts['non_retracted_count']

# Calculate the difference as a percentage of the total papers (avoiding division by zero)
country_year_counts['difference_percentage'] = (country_year_counts['difference'] / (country_year_counts['non_retracted_count'] + country_year_counts['retracted_count']).replace(0, np.nan)) * 100

# Select top 100 entries based on the highest total counts (sum of non-retracted and retracted)
top_100 = country_year_counts.nlargest(100, ['non_retracted_count', 'retracted_count'])

# Generate unique x positions for each country-year pair
x_labels = [f"{row['country']}_{row['year']}" for _, row in top_100.iterrows()]
x_positions = np.arange(len(x_labels))

# Initialize plot
fig, ax1 = plt.subplots(figsize=(18, 8))

# Plot bars for the total difference between retracted and non-retracted counts
ax1.bar(x_positions, top_100['difference'], width=0.4, color='blue', label='Difference (Retracted - Non-Retracted)')
ax1.set_xlabel('Country-Year')
ax1.set_ylabel('Total Difference', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_xticks(x_positions)
ax1.set_xticklabels(x_labels, rotation=90)

# Create a second y-axis to plot the percentage difference
ax2 = ax1.twinx()
ax2.plot(x_positions, top_100['difference_percentage'], color='red', marker='o', linestyle='dashed', label='Difference %')
ax2.set_ylabel('Difference (%)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Title and legend
fig.suptitle('Total and Percentage Difference of Retracted vs Non-Retracted Papers per Country-Year')
ax1.axhline(0, color='black', linewidth=1)
fig.tight_layout()
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# ## Generating Final Corpus

# %% [markdown]
# Having checked the country and year distribution of our papers, we can go ahead and generate a single data frame with the corpus that we will use to train our data set:

# %%
# Concatenate data frames with abstracts with both retracted and non-retracted papers

df_corpus = pd.concat([df_retracted, df_non_retracted], ignore_index=True)

# Reshuffle rows to mix retracted and non-retracted texts

df_corpus = df_corpus.sample(frac=1).reset_index(drop=True)

# Enforce integer type for target

df_corpus['target'] = df_corpus['target'].astype(int)

# Visualize corpus data frame

df_corpus.head()
# Out:
#                                        abstract_text  target  \
# 0  "Atrial fibrosis occurs frequently with struct...       1
# 1  "In Brief Purpose To determine the safety and ...       1
# 2  "Biglycan (BGN) is an important component of t...       0
# 3  "Fusarium wilt caused by Fusarium oxysporum f....       0
# 4  "The genome of Stenotrophomonas maltophilia en...       1
#
#                                 doi country  year  ret_flag
# 0        10.1038_s41420-022-00895-9      CN  2022     False
# 1  10.1097_00006982-200402000-00018      US  2004     False
# 2      10.1016_j.molonc.2016.08.002      CN  2016     False
# 3            10.3390_toxins12040254      CN  2020     False
# 4               10.1128_JB.00310-07      IE  2007     False

# %% [markdown]
# ## Output

# %% [markdown]
# To conclude, we will save the corpus stored in our data frame into a .csv file:

# %%
# Save content of data frame to .csv

df_corpus.to_csv(output_path, sep=',', index=False)
