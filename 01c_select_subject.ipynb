# %% [markdown]
# # 1c. Data Cleaning: Dividing our Data Set Based on the "Subject" Column

# %% [markdown]
# ## Introduction

# %% [markdown]
# This Notebook generates **a data frame with all the retracted papers in our data set from a specific field from the "Subject" column**, which will be selected by hand. Note that, since the "subject" column often mentions more than one subject, a single paper may be associated to more than one scientific field.
#
# The Notebook takes as input the clean data set generated by **Notebook 1b**, which is already filtered by severity score. The output that it generates will in turn be used by **Notebook 2a** in order to fetch text data from retracted papers.
#
# The **workflow** is as follows:
#
# - Input parameters: **one .csv** file with the clean data set with retracted papers filtered by severity score.
# - Output parameters: as many **.csv files** as unique entries there are in the "subject" column of the input .csv file.

# %% [markdown]
# ## Input / Output Parameters

# %% [markdown]
# Input parameters:

# %%
# File path for input .csv file

input_path = "../data/retraction_watch_data_set/3_severe_only_data_set.csv"

# Code for subject to restrict analysis to

subject = "(BLS) Biology - Cellular"

# %% [markdown]
# Output parameters:

# %%
# File path for output .csv

output_path = '../data/retraction_watch_data_set/4_cell_bio_data_set.csv'

# %% [markdown]
# ## Importing Libraries

# %%
# Import required libraries

import pandas as pd
import numpy as np
import function_definitions

# %% [markdown]
# ## Selecting a Subject

# %% [markdown]
# Let us start by loading our data from our .csv file into a dataframe:

# %%
# Read data from .csv file 

df = pd.read_csv(input_path, encoding='latin-1')

# Visualize first row of data frame

df.head(1)
# Out:
#    record_id                                              title  \
# 0      52765  An integrated 3D model based face recognition ...
#
#                                 subject  \
# 0  (B/T) Data Science;(B/T) Technology;
#
#                                          institution              journal  \
# 0  Management Information System Department, Cypr...  Applied Nanoscience
#
#   publisher country                   author  \
# 0  Springer  Turkey  Ali Milad;Kamil Yurtkan
#
#                                                 urls       article_type  ...  \
# 0  https://retractionwatch.com/2024/01/26/springe...  Research Article;  ...
#
#   retraction_pubmed_id original_paper_date          original_paper_doi  \
# 0                  0.0       2/3/2022 0:00  10.1007/s13204-021-02123-9
#
#   original_paper_pubmed_id retraction_nature  \
# 0                      0.0        Correction
#
#                                    reason paywalled  \
# 0  +Error in Text;+Updated to Retraction;        No
#
#                                                notes  \
# 0  See also: https://pubpeer.com/publications/BCC...
#
#                                   reason_list severity_score
# 0  ['Error in Text', 'Updated to Retraction']              3
#
# [1 rows x 22 columns]

# %% [markdown]
# Let us now take a look at the "subject" column:

# %%
df.subject
# Out:
# 0                     (B/T) Data Science;(B/T) Technology;
# 1        (B/T) Data Science;(B/T) Technology;(PHY) Engi...
# 2                                        (B/T) Technology;
# 3        (B/T) Technology;(HSC) Medicine - General;(HSC...
# 4                        (B/T) Technology;(SOC) Education;
#                                ...
# 52285    (BLS) Biochemistry;(HSC) Medicine - Cardiology...
# 52286    (BLS) Biology - Cellular;(BLS) Genetics;(BLS) ...
# 52287    (BLS) Biology - Cellular;(BLS) Genetics;(BLS) ...
# 52288    (BLS) Biology - Cancer;(BLS) Biology - Cellula...
# 52289    (BLS) Biology - Cellular;(BLS) Biology - Molec...
# Name: subject, Length: 52290, dtype: object

# %% [markdown]
# As we can see, the different rows in this column often contain more than one subject separated by a semicolon. It will be useful to find out how many unique subjects there are in our data frame:

# %%
# Create series with all subjects by splitting and exploding entries in subject column

subjects_series = df['subject'].str.split(';').explode()

# Obtain list with unique subjects from series

unique_subjects_list = sorted(subjects_series.unique())

# Visualize unique subjects

unique_subjects_list
# Out:
# ['',
#  '(B/T) Business - Accounting',
#  '(B/T) Business - Economics',
#  '(B/T) Business - General',
#  '(B/T) Business - Management',
#  '(B/T) Business - Manufacturing',
#  '(B/T) Business - Marketing',
#  '(B/T) Business - Public Relations',
#  '(B/T) Computer Science',
#  '(B/T) Data Science',
#  '(B/T) Foreign Aid',
#  '(B/T) Government',
#  '(B/T) International Relations',
#  '(B/T) Technology',
#  '(B/T) Transportation',
#  '(B/T) Urban Planning',
#  '(BLS) Agriculture',
#  '(BLS) Anatomy/Physiology',
#  '(BLS) Anthropology',
#  '(BLS) Archeology',
#  '(BLS) Biochemistry',
#  '(BLS) Biology - Cancer',
#  '(BLS) Biology - Cellular',
#  '(BLS) Biology - General',
#  '(BLS) Biology - Molecular',
#  '(BLS) Forensic Sciences',
#  '(BLS) Genetics',
#  '(BLS) Microbiology',
#  '(BLS) Neuroscience',
#  '(BLS) Nutrition',
#  '(BLS) Paleontology',
#  '(BLS) Parasitology',
#  '(BLS) Plant Biology/Botany',
#  '(BLS) Toxicology',
#  '(BLS) Zoology',
#  '(ENV) Climate Change',
#  '(ENV) Climatology',
#  '(ENV) Ecology',
#  '(ENV) Environmental Sciences',
#  '(ENV) Food Science',
#  '(ENV) Ground/Surface Water',
#  '(HSC) Biostatistics/Epidemiology',
#  '(HSC) Medicine - Alternative',
#  '(HSC) Medicine - Anesthesia/Anaesthesia',
#  '(HSC) Medicine - Cardiology',
#  '(HSC) Medicine - Cardiovascular',
#  '(HSC) Medicine - Dentistry',
#  '(HSC) Medicine - Dermatology',
#  '(HSC) Medicine - Diabetes',
#  '(HSC) Medicine - Drug Design',
#  '(HSC) Medicine - Endocrinology',
#  '(HSC) Medicine - Gastroenterology',
#  '(HSC) Medicine - General',
#  '(HSC) Medicine - Geriatric',
#  '(HSC) Medicine - Immunology',
#  '(HSC) Medicine - Infectious Disease',
#  '(HSC) Medicine - Internal',
#  '(HSC) Medicine - Neurology',
#  '(HSC) Medicine - Nursing',
#  '(HSC) Medicine - Obstetrics/Gynecology',
#  '(HSC) Medicine - Oncology',
#  '(HSC) Medicine - Ophthalmology',
#  '(HSC) Medicine - Orthopedics',
#  '(HSC) Medicine - Otorhinolaryngology',
#  '(HSC) Medicine - Pathology',
#  '(HSC) Medicine - Pediatrics',
#  '(HSC) Medicine - Pharmacology',
#  '(HSC) Medicine - Psychiatry',
#  '(HSC) Medicine - Pulmonology',
#  '(HSC) Medicine - Rehabilitation/Therapy',
#  '(HSC) Medicine - Sports',
#  '(HSC) Medicine - Surgery',
#  '(HSC) Medicine - Transplantation',
#  '(HSC) Medicine - Urology/Nephrology',
#  '(HSC) Nutrition',
#  '(HSC) Occupational Health and Safety',
#  '(HSC) Public Health and Safety',
#  '(HSC) Radiology/Imaging',
#  '(HSC) Sports Science',
#  '(HSC) Veterinary Science',
#  '(HUM) Architecture',
#  '(HUM) Arts - Biography',
#  '(HUM) Arts - Film Studies',
#  '(HUM) Arts - General',
#  '(HUM) Arts - Music',
#  '(HUM) Arts -Literature/Poetry',
#  '(HUM) Cartography',
#  '(HUM) History - Africa',
#  '(HUM) History - Asia',
#  '(HUM) History - Australia',
#  '(HUM) History - Europe',
#  '(HUM) History - General',
#  '(HUM) History - North America',
#  '(HUM) History - South America',
#  '(HUM) History - United States',
#  '(HUM) Journalism',
#  '(HUM) Philosophy',
#  '(HUM) Religion',
#  '(PHY) Astronomy',
#  '(PHY) Astrophysics',
#  '(PHY) Chemistry',
#  '(PHY) Cosmology',
#  '(PHY) Crystallography/Spectroscopy',
#  '(PHY) Energy',
#  '(PHY) Engineering - Chemical',
#  '(PHY) Engineering - Electrical',
#  '(PHY) Engineering - General',
#  '(PHY) Engineering - Mechanical',
#  '(PHY) Engineering - Structural',
#  '(PHY) Forensic Sciences',
#  '(PHY) Geology',
#  '(PHY) Hydrology',
#  '(PHY) Materials Science',
#  '(PHY) Mathematics',
#  '(PHY) Nanotechnology',
#  '(PHY) Physics',
#  '(PHY) Statistics',
#  '(SOC) Communications',
#  '(SOC) Criminology',
#  '(SOC) Education',
#  '(SOC) Ethics/Bioethics',
#  '(SOC) Forensics',
#  '(SOC) Law/Legal Issues',
#  '(SOC) Linguistics',
#  '(SOC) Military/Naval Studies',
#  '(SOC) Philosophy',
#  '(SOC) Political Science',
#  '(SOC) Psychology',
#  '(SOC) Sexual And Marital Studies',
#  '(SOC) Sociology',
#  '(SOC) Sports and Recreation']

# %% [markdown]
# It will also be useful to get a sense of how many papers we have per subject:

# %%
# Get series with value counts of each unique subject

subject_counts = subjects_series.value_counts()

# Visualize value counts

subject_counts
# Out:
# subject
#                                  52290
# (BLS) Biology - Cellular         10241
# (B/T) Technology                  7442
# (BLS) Genetics                    6595
# (BLS) Biochemistry                6067
#                                  ...
# (B/T) Foreign Aid                    9
# (HUM) History - South America        7
# (HUM) History - United States        7
# (PHY) Forensic Sciences              5
# (HUM) History - Australia            1
# Name: count, Length: 131, dtype: int64

# %% [markdown]
# In the future, we will be interested in studying papers that belong to a single area of study. In order to be able to do this, let us start by defining a function that restricts our data set to a single one of all the subjects present in our data set:

# %%
def subject_selector(df, subject):
    """
    Function takes a data frame and a string with a subject name as input.
    It processes the 'subject' column by splitting its values separated by semicolons, 
    filters the data frame to include only rows with the specified subject, then
    returns the filtered data frame.
    """

    # Create series with exploded subjects by splitting the 'subject' column
    
    exploded_subjects = df['subject'].str.split(';').explode()
    
    # Drop the original 'subject' column and join the exploded subjects
    
    df = df.drop('subject', axis=1).join(exploded_subjects.rename('subject'))
    
    # Filter the data frame for the specified subject
    
    subject_df = df[df['subject'] == subject]
    
    # Return filtered data frame
    
    return subject_df

# %% [markdown]
# Since it is the subject with the most entries, molecular biology will be a good test subject case for our study. Let us thus call our function to restrict our data frame to papers in these area only (recall that the value of the variable "df_subject" had already been set that way when defining our input parameters above):

# %%
# Call function to create one .csv file with all retracted papers per subject

df_subject = subject_selector(df, subject)

# Check that it worked

df_subject
# Out:
#        record_id                                              title  \
# 20         52739  Anti-breast Cancer Activity of Co(II) Complex ...
# 21         52738  Anticancer Activity of Zn(II) Coordination Pol...
# 32         52727  Predigested high-fat meats based on Lactobacil...
# 34         52725  Mechanical model of the physiological microenv...
# 106        52621  Design and evaluation of ciprofloxacin loaded ...
# ...          ...                                                ...
# 52281          9  Sphingosine kinase 1 regulates pro-inflammator...
# 52286          4  MtvR is a global small noncoding regulatory RN...
# 52287          3  The second RNA chaperone, Hfq2, is also requir...
# 52288          2  Regulation of Wnt/beta-catenin pathway by cPLA...
# 52289          1  Genistein protects genioglossus myocyte agains...
#
#                                              institution  \
# 20     Luohe Medical College, Luohe, Henan, China; Lu...
# 21     Department of Medical Genetics, School of Basi...
# 32     Department of Microbial Biotechnology, Genetic...
# 34     School of Information Engineering, East China ...
# 106    School of Biochemical Engineering, Indian Inst...
# ...                                                  ...
# 52281  Department of Physiology, Yong Loo Lin School ...
# 52286  Institute for Biotechnology and Bioengineering...
# 52287  IBBÃÂ¢ÃÂÃÂInstitute for Biotechnology and...
# 52288  Department of Pathology, University of Pittsbu...
# 52289   Tongji University, Shanghai, Shanghai Shi, China
#
#                                 journal                           publisher  \
# 20           Journal of Cluster Science  Springer - Nature Publishing Group
# 21           Journal of Cluster Science  Springer - Nature Publishing Group
# 32                  Applied Nanoscience                            Springer
# 34                  Applied Nanoscience                            Springer
# 106                Biomedical Materials                      IOP Publishing
# ...                                 ...                                 ...
# 52281    Journal of Cellular Physiology                               Wiley
# 52286           Journal of Bacteriology   American Society for Microbiology
# 52287           Journal of Bacteriology   American Society for Microbiology
# 52288  Journal of Cellular Biochemistry                               Wiley
# 52289  Journal of Cellular Biochemistry                               Wiley
#
#              country                                             author  \
# 20             China                  Ting Yin;Ruirui Wang;Shaozhe Yang
# 21             China                Hao Liu;Liying Wu;Jiji Cui;Dan Wang
# 32             Egypt          A B Abeer Mohammed;A E Hegazy;Ahmed Salah
# 34             China  Yuejin Zhang;Juan Wang;Qi Liu;Xiaohui Guan;Mei...
# 106            India  Satyavrat Tripathi;Bhisham Narayan Singh;Singh...
# ...              ...                                                ...
# 52281      Singapore        Liang Zhi;Bernard P Leung;Alirio J Melendez
# 52286       Portugal  Christian G Ramos;AndrÃÂÃÂ© M Grilo;Paulo J...
# 52287       Portugal  Christian G Ramos;SÃÂÃÂ­lvia A Sousa;AndrÃ...
# 52288  United States     Chang Han;Kyu Lim;Lihong Xu;Guiying Li;Tong Wu
# 52289          China                            Wanghui Ding;Yuehua Liu
#
#                                                     urls       article_type  \
# 20                                                   NaN  Research Article;
# 21                                                   NaN  Research Article;
# 32     https://retractionwatch.com/2024/01/26/springe...  Research Article;
# 34     https://retractionwatch.com/2024/01/26/springe...  Research Article;
# 106                                                  NaN  Research Article;
# ...                                                  ...                ...
# 52281  http://retractionwatch.com/2012/04/04/third-re...  Research Article;
# 52286  http://retractionwatch.com/2014/11/03/post-doc...  Research Article;
# 52287  http://retractionwatch.com/2014/10/17/this-sit...  Research Article;
# 52288  http://retractionwatch.com/2015/02/09/figure-d...  Research Article;
# 52289                                                NaN  Research Article;
#
#       retraction_date  ... original_paper_date          original_paper_doi  \
# 20     1/24/2024 0:00  ...     10/27/2021 0:00  10.1007/s10876-021-02192-4
# 21     1/30/2024 0:00  ...     11/23/2021 0:00  10.1007/s10876-021-02201-6
# 32     1/11/2024 0:00  ...      5/17/2021 0:00  10.1007/s13204-021-01879-4
# 34      1/9/2024 0:00  ...      7/19/2021 0:00  10.1007/s13204-021-01951-z
# 106     3/5/2024 0:00  ...      2/23/2021 0:00    10.1088/1748-605X/abd1b8
# ...               ...  ...                 ...                         ...
# 52281  3/20/2012 0:00  ...      3/30/2006 0:00           10.1002/jcp.20646
# 52286  11/1/2014 0:00  ...      5/31/2013 0:00         10.1128/JB.00242-13
# 52287  11/1/2014 0:00  ...      1/28/2011 0:00         10.1128/JB.01375-10
# 52288  1/29/2015 0:00  ...      7/17/2008 0:00           10.1002/jcb.21852
# 52289  3/15/2012 0:00  ...      5/19/2011 0:00           10.1002/jcb.23190
#
#       original_paper_pubmed_id retraction_nature  \
# 20                         0.0        Retraction
# 21                         0.0        Retraction
# 32                         0.0        Retraction
# 34                         0.0        Retraction
# 106                 33291087.0        Retraction
# ...                        ...               ...
# 52281               16575915.0        Retraction
# 52286                2372964.0        Retraction
# 52287               21278292.0        Retraction
# 52288               18636547.0        Retraction
# 52289                      0.0        Retraction
#
#                                                   reason paywalled  \
# 20     +Concerns/Issues About Image;+Concerns/Issues ...        No
# 21     +Concerns/Issues About Image;+Concerns/Issues ...        No
# 32     +Concerns/Issues about Referencing/Attribution...        No
# 34     +Concerns/Issues about Referencing/Attribution...        No
# 106    +Concerns/Issues About Image;+Duplication of I...        No
# ...                                                  ...       ...
# 52281  +Duplication of Image;+Investigation by Compan...        No
# 52286     +Duplication of Image;+Manipulation of Images;        No
# 52287             +Duplication of Image;+Error in Image;        No
# 52288  +Duplication of Image;+Falsification/Fabricati...        No
# 52289         +Investigation by Third Party;+Withdrawal;        No
#
#                                                    notes  \
# 20     See also: https://pubpeer.com/publications/739...
# 21     See also: https://pubpeer.com/publications/297...
# 32     See also: https://pubpeer.com/publications/430...
# 34     See also: https://pubpeer.com/publications/73D...
# 106                                                  NaN
# ...                                                  ...
# 52281                                                NaN
# 52286                   exact date of retraction unknown
# 52287                                                NaN
# 52288                                                NaN
# 52289                                                NaN
#
#                                              reason_list severity_score  \
# 20     ['Concerns/Issues About Image', 'Concerns/Issu...              4
# 21     ['Concerns/Issues About Image', 'Concerns/Issu...              4
# 32     ['Concerns/Issues about Referencing/Attributio...              3
# 34     ['Concerns/Issues about Referencing/Attributio...              3
# 106    ['Concerns/Issues About Image', 'Duplication o...              3
# ...                                                  ...            ...
# 52281  ['Duplication of Image', 'Investigation by Com...              4
# 52286  ['Duplication of Image', 'Manipulation of Imag...              2
# 52287         ['Duplication of Image', 'Error in Image']              2
# 52288  ['Duplication of Image', 'Falsification/Fabric...              3
# 52289     ['Investigation by Third Party', 'Withdrawal']              3
#
#                         subject
# 20     (BLS) Biology - Cellular
# 21     (BLS) Biology - Cellular
# 32     (BLS) Biology - Cellular
# 34     (BLS) Biology - Cellular
# 106    (BLS) Biology - Cellular
# ...                         ...
# 52281  (BLS) Biology - Cellular
# 52286  (BLS) Biology - Cellular
# 52287  (BLS) Biology - Cellular
# 52288  (BLS) Biology - Cellular
# 52289  (BLS) Biology - Cellular
#
# [10241 rows x 22 columns]

# %% [markdown]
# As always, it will be useful to get an idea of how many papers we have in our filtered data set, and of what percentage of the data set that we loaded at the beginning of this notebook that represents:

# %%
# Print total number of papers in data set

print(f"Total number of papers in data set: {df_subject.shape[0]}")

# Print percentage of papers retained compare with initial data set

print(f"Percentage of original data set that represents: {round(df_subject.shape[0] *100 / df.shape[0],2)} %")
# Out:
# Total number of papers in data set: 10241
# Percentage of original data set that represents: 19.59 %

# %% [markdown]
# ## Output

# %% [markdown]
# Having done all this, we can now go ahead safe our new data frame, which has been restricted to a single subject, into a .csv file:

# %%
# Save date frame as .csv

df_subject.to_csv(output_path, index=False)
